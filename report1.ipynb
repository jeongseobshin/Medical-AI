# %%
1-2
# Out:
# -1

# %%
4*5
# Out:
# 20

# %%
7/5
# Out:
# 1.4

# %%
3**2
# Out:
# 9

# %%
type(10)
# Out:
# int

# %%
type(1.7)
# Out:
# float

# %%
type('hello')
# Out:
# str

# %%
x=10
print(x)

y=3.14
x*y
# Out:
# 10
# 31.400000000000002

# %%
a=[1,2,3,4,5]
print(a)
len(a)
a[0]
# Out:
# [1, 2, 3, 4, 5]
# 1

# %%
a[4]=90
print(a)
# Out:
# [1, 2, 3, 4, 90]

# %%
a[0:2]
# Out:
# [1, 2]

# %%
a[:3]
# Out:
# [1, 2, 3]

# %%
a[:-1]
# Out:
# [1, 2, 3, 4]

# %%
me = {'height':180}
me['height']
# Out:
# 180

# %%
me['height']=70
print(me)
# Out:
# {'height': 70}

# %%
sum = 0
for i in range(0,10,1):
  sum = sum + i
  print(i,sum)
# Out:
# 0 0
# 1 1
# 2 3
# 3 6
# 4 10
# 5 15
# 6 21
# 7 28
# 8 36
# 9 45

# %%
def maximum(x,y):
  if x>y:
    return x
  elif x==y:
    return 'The numbers are equal'
  else:
    return y
print(maximum(2,3))
# Out:
# 3

# %%
class Person:
  def __init__(self,name):
    self.name = name
  def say_hi(self):
    print('Hello, my name is', self.name)

p=Person('파이썬')
p.say_hi()
# Out:
# Hello, my name is 파이썬

# %%
major_g = {'1학년':5,'2학년':9,'3학년':12,'4학년':12}
print(major_g)
print(major_g['2학년'])

major_g['2학년'] = 11
print(major_g['2학년'])
# Out:
# {'1학년': 5, '2학년': 9, '3학년': 12, '4학년': 12}
# 9
# 11

# %%
import numpy as np
x = np.array([1.0,2.0,3.0])
print (x)
type (x)
# Out:
# [1. 2. 3.]
# numpy.ndarray

# %%
y = np.array([2.0,4.0,6.0])
x+y
# Out:
# array([3., 6., 9.])

# %%
x-y
# Out:
# array([-1., -2., -3.])

# %%
x*y
# Out:
# array([ 2.,  8., 18.])

# %%
x/y
# Out:
# array([0.5, 0.5, 0.5])

# %%
x/2
# Out:
# array([0.5, 1. , 1.5])

# %%
A = np.array([[1,2],[3,4]])
print (A)
# Out:
# [[1 2]
#  [3 4]]

# %%
A.shape
# Out:
# (2, 2)

# %%
A.dtype
# Out:
# dtype('int64')

# %%
B = np.array([[3,0],[0,6]])
A+B
# Out:
# array([[ 4,  2],
#        [ 3, 10]])

# %%
A*B
# Out:
# array([[ 3,  0],
#        [ 0, 24]])

# %%
A*10
# Out:
# array([[10, 20],
#        [30, 40]])

# %%
A = np.array([[1,2],[3,4]])
B = np.array([10,20])
A*B
# Out:
# array([[10, 40],
#        [30, 80]])

# %%
X = np.array([[51,55],[14,19],[9,4]])
print (X)
# Out:
# [[51 55]
#  [14 19]
#  [ 9  4]]

# %%
X[0]
# Out:
# array([51, 55])

# %%
X[0][1]
# Out:
# 55

# %%
for row in X:
    print (row)
# Out:
# [51 55]
# [14 19]
# [9 4]

# %%
X = X.flatten()
print (X)
# Out:
# [51 55 14 19  9  4]

# %%
X[np.array([0,2,4])]
# Out:
# array([51, 14,  9])

# %%
X > 15
# Out:
# array([ True,  True, False,  True, False, False])

# %%
X[X>15]
# Out:
# array([51, 55, 19])
